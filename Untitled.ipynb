# %%
#from model import ClassPredictor
token = '????'
import torch
#from config import reply_texts
reply_texts = {
    'pred_answer': 'I predicted class with index {}. To show class name you will need to extract it from' +
                   'dataloader you used while training'
}
import numpy as np
from PIL import Image
from io import BytesIO

# %%
torch.__version__
# Out:
# '1.1.0'

# %%
import torchvision.transforms as transforms
import torchvision.models as models

from fastai.vision import load_learner, Image

# В данном классе мы хотим полностью производить всю обработку картинок, которые поступают к нам из телеграма.
# Это всего лишь заготовка, поэтому не стесняйтесь менять имена функций, добавлять аргументы, свои классы и
# все такое.
class ClassPredictor:
    def __init__(self):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = load_learner('C:/Users/Serg/Documents/Neyro_sets/juputers/bot_classify/')
        self.to_tensor = transforms.ToTensor()

    def predict1(self, img_stream):
        # Этот метод по переданным картинкам в каком-то формате (PIL картинка, BytesIO с картинкой
        # или numpy array на ваш выбор). В телеграм боте мы получаем поток байтов BytesIO,
        # а мы хотим спрятать в этот метод всю работу с картинками, поэтому лучше принимать тут эти самые потоки
        # и потом уже приводить их к PIL, а потом и к тензору, который уже можно отдать модели.
        # Не забудьте перенести все трансофрмации, которые вы использовали при тренировке
        # Для этого будет удобно сохранить питоновский объект с ними в виде файла с помощью pickle,
        # а потом загрузить здесь.

        # Обработка картинки сейчас производится в методе process image, а здесь мы должны уже применить нашу
        # модель и вернуть вектор предсказаний для нашей картинки

        # Для наглядности мы сначала переводим ее в тензор, а потом обратно
        #print(self.process_image(img_stream))
        return self.model.predict(self.process_image(img_stream))[0]

    # В predict используются некоторые внешние функции, их можно добавить как функции класса
    # Если понятно, что функция является служебной и снаружи использоваться не должна, то перед именем функции
    # принято ставить _ (выглядит это так: def _foo() )
    # ниже пример того, как переносить методы
    def process_image(self, img_stream):
        # используем PIL, чтобы получить картинку из потока и изменить размер
        image = PIL_Image.open(img_stream).resize((256, 256))
        # переводим картинку в тензор и оборачиваем в объект Image, который использует fastai у себя внутри
        image = Image(self.to_tensor(image))
        
        return image

# %%
model = ClassPredictor()
# Out:
# C:\Users\Serg\Anaconda3\lib\site-packages\torch\serialization.py:454: SourceChangeWarning: source code of class 'fastai.layers.AdaptiveConcatPool2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# C:\Users\Serg\Anaconda3\lib\site-packages\torch\serialization.py:454: SourceChangeWarning: source code of class 'fastai.layers.Flatten' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
def text (bot,update):
    chat_id = update.message.chat_id
    print(update)
    ans = 'kk'
    if(update['message']['text'] == "start" or update['message']['text'] == "help"):
        ans = 'Привет, дорогой друг, рады что ты к нам загленул. Этот бот умеет классифицировать ' + 'овощи, фрукты и ягоды. Просто пришли мне картинку и я скажу что это. '
    else :
        ans = 'я тебя не понимаю пришли help или картинку'
    update.message.reply_text(ans)

# %%
def send_prediction_on_photo(bot, update):
    chat_id = update.message.chat_id
    print("Got image from {}".format(chat_id))

    # получаем информацию о картинке
    image_info = update.message.photo[-1]
    image_file = bot.get_file(image_info)
    image_stream = BytesIO()
    image_file.download(out=image_stream)
    print('load image')
    class_ = model.predict1(image_stream)
    
    ans = 'я думаю это ' + str(class_) + ', но если ты хочешь добиться большей точности то сфоткай фрукт на белоим фоне'
    # теперь отправим результат
    update.message.reply_text(ans)
    print("Sent Answer to user, predicted: {}".format(class_))

# %%
from PIL import Image as PIL_Image
import matplotlib.pyplot as plt
if __name__ == '__main__':
    from telegram.ext import Updater, MessageHandler, Filters
    import logging
    import telegram
    # Включим самый базовый логгинг, чтобы видеть сообщения об ошибках
    logging.basicConfig(
         format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
         level=logging.INFO)
    # используем прокси, так как без него у меня ничего не работало(
    updater = Updater(token=token)
    updater.dispatcher.add_handler(MessageHandler(Filters.photo, send_prediction_on_photo))
    updater.dispatcher.add_handler(MessageHandler(Filters.text, text))
    updater.start_polling()
# Out:
# 2019-06-27 20:26:17,763 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234AE70E80>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 20:26:24,075 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234B34B5C0>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 20:26:29,089 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234BD1B3C8>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 20:26:30,963 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234BD1B780>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# {'update_id': 333238343, 'message': {'message_id': 90, 'date': 1561656389, 'chat': {'id': 542373574, 'type': 'private', 'first_name': 'Сергей', 'last_name': 'Вольнов'}, 'text': 'll', 'entities': [], 'caption_entities': [], 'photo': [], 'new_chat_members': [], 'new_chat_photo': [], 'delete_chat_photo': False, 'group_chat_created': False, 'supergroup_chat_created': False, 'channel_chat_created': False, 'from': {'id': 542373574, 'first_name': 'Сергей', 'is_bot': False, 'last_name': 'Вольнов', 'language_code': 'ru'}}, '_effective_message': {'message_id': 90, 'date': 1561656389, 'chat': {'id': 542373574, 'type': 'private', 'first_name': 'Сергей', 'last_name': 'Вольнов'}, 'text': 'll', 'entities': [], 'caption_entities': [], 'photo': [], 'new_chat_members': [], 'new_chat_photo': [], 'delete_chat_photo': False, 'group_chat_created': False, 'supergroup_chat_created': False, 'channel_chat_created': False, 'from': {'id': 542373574, 'first_name': 'Сергей', 'is_bot': False, 'last_name': 'Вольнов', 'language_code': 'ru'}}}
# 2019-06-27 20:26:32,358 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:32,366 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# {'update_id': 333238344, 'message': {'message_id': 92, 'date': 1561656400, 'chat': {'id': 542373574, 'type': 'private', 'first_name': 'Сергей', 'last_name': 'Вольнов'}, 'text': 'help', 'entities': [], 'caption_entities': [], 'photo': [], 'new_chat_members': [], 'new_chat_photo': [], 'delete_chat_photo': False, 'group_chat_created': False, 'supergroup_chat_created': False, 'channel_chat_created': False, 'from': {'id': 542373574, 'first_name': 'Сергей', 'is_bot': False, 'last_name': 'Вольнов', 'language_code': 'ru'}}, '_effective_message': {'message_id': 92, 'date': 1561656400, 'chat': {'id': 542373574, 'type': 'private', 'first_name': 'Сергей', 'last_name': 'Вольнов'}, 'text': 'help', 'entities': [], 'caption_entities': [], 'photo': [], 'new_chat_members': [], 'new_chat_photo': [], 'delete_chat_photo': False, 'group_chat_created': False, 'supergroup_chat_created': False, 'channel_chat_created': False, 'from': {'id': 542373574, 'first_name': 'Сергей', 'is_bot': False, 'last_name': 'Вольнов', 'language_code': 'ru'}}}
# 2019-06-27 20:26:40,922 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:40,928 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:41,996 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:41,997 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:46,047 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:46,056 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:47,602 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:47,607 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:52,164 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:52,171 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:57,468 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:57,472 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:58,558 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:26:58,580 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# {'update_id': 333238345, 'message': {'message_id': 94, 'date': 1561656420, 'chat': {'id': 542373574, 'type': 'private', 'first_name': 'Сергей', 'last_name': 'Вольнов'}, 'text': 'start', 'entities': [], 'caption_entities': [], 'photo': [], 'new_chat_members': [], 'new_chat_photo': [], 'delete_chat_photo': False, 'group_chat_created': False, 'supergroup_chat_created': False, 'channel_chat_created': False, 'from': {'id': 542373574, 'first_name': 'Сергей', 'is_bot': False, 'last_name': 'Вольнов', 'language_code': 'ru'}}, '_effective_message': {'message_id': 94, 'date': 1561656420, 'chat': {'id': 542373574, 'type': 'private', 'first_name': 'Сергей', 'last_name': 'Вольнов'}, 'text': 'start', 'entities': [], 'caption_entities': [], 'photo': [], 'new_chat_members': [], 'new_chat_photo': [], 'delete_chat_photo': False, 'group_chat_created': False, 'supergroup_chat_created': False, 'channel_chat_created': False, 'from': {'id': 542373574, 'first_name': 'Сергей', 'is_bot': False, 'last_name': 'Вольнов', 'language_code': 'ru'}}}
# 2019-06-27 20:27:01,993 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:01,998 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:18,497 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:18,503 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:19,557 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:19,560 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:23,629 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:23,632 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:25,215 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:25,217 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:29,769 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:29,774 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:36,722 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D2E8CC0>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 20:27:37,266 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:37,272 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:27:52,462 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234B34B198>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 20:27:57,471 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x0000002341DAFDA0>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 20:27:58,702 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234AE70F28>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 20:28:01,998 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:02,002 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:06,050 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:06,058 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:13,006 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234BD1BF60>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 20:28:17,059 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D2F21D0>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 20:28:20,385 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:20,393 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:21,445 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:21,449 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:26,065 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:26,074 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:30,737 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:30,745 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:41,228 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:41,230 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:42,296 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:42,317 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:46,366 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:46,369 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:47,962 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:47,970 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:52,522 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:52,533 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:28:59,473 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234B34B198>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 20:29:00,014 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:29:00,017 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:29:04,072 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:29:04,079 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:29:04,148 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# 2019-06-27 20:29:04,155 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 233, in _request_wrapper
#     raise NetworkError('{0} ({1})'.format(message, resp.status))
# telegram.error.NetworkError: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running (409)
# ...
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 209, in _request_wrapper
#     raise NetworkError('urllib3 HTTPError {0}'.format(error))
# telegram.error.NetworkError: urllib3 HTTPError HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates (Caused by ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D15D9E8>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)'))
# 2019-06-27 21:18:55,102 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D15D978>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 21:18:55,131 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D15DFD0>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 21:19:00,123 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D15DD30>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 21:19:00,142 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D15DF98>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 21:19:05,289 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D14C358>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 21:19:05,594 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None)) after connection broken by 'ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D14C2B0>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')': /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates
# 2019-06-27 21:19:10,303 - telegram.ext.updater - ERROR - Error while getting Updates: urllib3 HTTPError HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates (Caused by ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D14C0B8>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)'))
# 2019-06-27 21:19:10,311 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\util\connection.py", line 83, in create_connection
#     raise err
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\util\connection.py", line 73, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 617, in urlopen
#     chunked=chunked)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 360, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 857, in _validate_conn
#     super(HTTPSConnectionPool, self)._validate_conn(conn)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 289, in _validate_conn
#     conn.connect()
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connection.py", line 146, in _new_conn
#     (self.host, self.timeout))
# telegram.vendor.ptb_urllib3.urllib3.exceptions.ConnectTimeoutError: (<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D14C0B8>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 203, in _request_wrapper
#     resp = self._con_pool.request(*args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\request.py", line 70, in request
#     **urlopen_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\request.py", line 148, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\poolmanager.py", line 244, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 695, in urlopen
#     **response_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 695, in urlopen
#     **response_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 695, in urlopen
#     **response_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 666, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\util\retry.py", line 376, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# telegram.vendor.ptb_urllib3.urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates (Caused by ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D14C0B8>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 209, in _request_wrapper
#     raise NetworkError('urllib3 HTTPError {0}'.format(error))
# telegram.error.NetworkError: urllib3 HTTPError HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates (Caused by ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D14C0B8>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)'))
# 2019-06-27 21:19:10,670 - telegram.ext.updater - ERROR - Error while getting Updates: urllib3 HTTPError HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates (Caused by ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D14C710>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)'))
# 2019-06-27 21:19:10,678 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\util\connection.py", line 83, in create_connection
#     raise err
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\util\connection.py", line 73, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 617, in urlopen
#     chunked=chunked)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 360, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 857, in _validate_conn
#     super(HTTPSConnectionPool, self)._validate_conn(conn)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 289, in _validate_conn
#     conn.connect()
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connection.py", line 146, in _new_conn
#     (self.host, self.timeout))
# telegram.vendor.ptb_urllib3.urllib3.exceptions.ConnectTimeoutError: (<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D14C710>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 203, in _request_wrapper
#     resp = self._con_pool.request(*args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\request.py", line 70, in request
#     **urlopen_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\request.py", line 148, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\poolmanager.py", line 244, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 695, in urlopen
#     **response_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 695, in urlopen
#     **response_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 695, in urlopen
#     **response_kw)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py", line 666, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\util\retry.py", line 376, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# telegram.vendor.ptb_urllib3.urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates (Caused by ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D14C710>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 319, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\ext\updater.py", line 280, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 65, in decorator
#     result = func(self, *args, **kwargs)
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\bot.py", line 1975, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 309, in post
#     headers={'Content-Type': 'application/json'})
#   File "C:\Users\Serg\Anaconda3\lib\site-packages\telegram\utils\request.py", line 209, in _request_wrapper
#     raise NetworkError('urllib3 HTTPError {0}'.format(error))
# telegram.error.NetworkError: urllib3 HTTPError HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot865937984:AAHhHwLNqIQpCfyd105oDCtTQH80JK049Ss/getUpdates (Caused by ConnectTimeoutError(<telegram.vendor.ptb_urllib3.urllib3.connection.VerifiedHTTPSConnection object at 0x000000234D14C710>, 'Connection to api.telegram.org timed out. (connect timeout=5.0)'))
